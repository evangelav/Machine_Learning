# %% [markdown]
# <a href="https://colab.research.google.com/github/evangelav/Machine_Learning/blob/main/BIN3100_ML_S2_Exercices_NumPy_et_Panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #BIN3100 ML S2 : Théorie
#
# ##Vidéos obligatoires
# Nous vous demandons de regarder et de compredre les vidéos suivante:
#
# 1.   [NumPy : Tableaux à n dimensions](https://www.youtube.com/watch?v=NzDQTrqsxas&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=10)
# 2.   [NumPy : Indexig, Slicing, Masking](https://www.youtube.com/watch?v=vw4u9uBFFqU&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=11)
# 3.   [NumPy : Mathématiques, Statistiques ](https://www.youtube.com/watch?v=RwFiNlL4Q8g&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=12)
# 4.   [NumPy : Broadcasting ](https://www.youtube.com/watch?v=lIESSFHGalA&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=13)
# 5.   [Panda : Introduction + Analyse du titanic](https://www.youtube.com/watch?v=zZkNOdBWgFQ&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=17)
# 6.   [Panda : Time Series](https://www.youtube.com/watch?v=qHRLG5hsW9I&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=18)
#
#
# A la fin de chaque vidéo, un exercice est proposé. Vous retrouverez ces exercices dans la Partie 1 des exercices de cette semaine
#
# ## Les vidéos suivantes sont en bonus:
#
# 7.  [MatPlotLib : Les Bases ](https://www.youtube.com/watch?v=O_OeWxpnUc0&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=14)
# 8.  [MatPlotLib : Graphiques Importants ](https://www.youtube.com/watch?v=MILtbfrMGL4&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=15)
# 9.  [SeaBorn : Les plus beaux graphiques](https://www.youtube.com/watch?v=xYgfIRzNPlo&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=19)

# %% [markdown]
# # Partie 1: Exercices relatifs aux Vidéos Machine Learnia
#
# https://www.youtube.com/playlist?list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq

# %% [markdown]
# ## Vidéos (10/30):
# [NumPy : Tableaux à n dimensions](https://www.youtube.com/watch?v=NzDQTrqsxas&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=10)
#
# Ecrivez une fonction qui va générer une matrice de nombres réels qui aura n lignes et m+1 colonnes. Dans les m premières colonnes les nombres seront choisis aléatoirement selon une distribution normale et la dernière colonne sera remplie de 1.

# %%
import numpy as np

# %%
def initialisation(n,m):
  # n : nombre de lignes
  # m : nombre de colonnes
  # renvoie une matrice n x (m+1) avec des nombres aléatoires (selon une distribution normale) dans les m premières colonnes 
  # et des 1 dans la dernière colonne
  A = np.random.randn(n, m)
  print(A)
  B = np.ones((n,1))
  print(B)
  C = np.concatenate((A, B), axis=1)
  return C

# %%
initialisation(3, 3)
# Out:
# [[ 0.16823288  0.16530796 -0.08703835]
#  [-0.67349897 -0.4245392  -0.63537743]
#  [-1.0864142  -0.96992377 -0.57608982]]
# [[1.]
#  [1.]
#  [1.]]
# array([[ 0.16823288,  0.16530796, -0.08703835,  1.        ],
#        [-0.67349897, -0.4245392 , -0.63537743,  1.        ],
#        [-1.0864142 , -0.96992377, -0.57608982,  1.        ]])

# %% [markdown]
# ## Vidéos (11/30):
# [NumPy : Indexig, Slicing, Masking](https://www.youtube.com/watch?v=vw4u9uBFFqU&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=11)
#
# Soit p un entier et M un ndarray.
#
# Ecrivez une fonction zoom(M,p) qui renvoie un ndarray qui est la sous-matrice contenant les éléments se trouvant dasn les p % centraux de la matrice M.
#
# Par exemple si la matrice de départ à 20 lignes et 20 colonnes (400 éléments)
# et que l'on demande les 25% centraux.
#
# Il faudra renvoyer la sous-matrice 10x10 (100 éléments) se trouvant au centre de la matrice. Donc les éléments aux indices de lignes et de colonnes entre 5 et 15.

# %%
def zoom(M,p):
  #M : la matrice sur laquelle on va "zoomer"
  #p : le pourcentage central de la matrice à renvoyer
  dim = M.shape
  lignes = dim[0]
  colonnes = dim[1]
  z_li = round(lignes*p/1000)
  z_col = round(colonnes*p/1000)
  z_li = round(z_li/2)
  z_col = round(z_col/2)
  Zoom = np.array((lignes-z_li, colonnes-z_col))
  Zoom = M[z_li:lignes-z_li, z_col:colonnes-z_col]
  return Zoom

# %%
zoom(face, 25)
# Out:
# array([[174, 164, 162, ..., 114, 124, 132],
#        [183, 183, 184, ..., 114, 125, 128],
#        [183, 186, 185, ..., 103, 110, 111],
#        ...,
#        [155, 160, 161, ..., 134, 136, 137],
#        [155, 159, 158, ..., 135, 137, 138],
#        [155, 158, 155, ..., 138, 139, 141]], dtype=uint8)

# %% [markdown]
# Exécuter la cellule ci-dessous pour tester votre fonction.
#
# La photo du raton-laveur et son zoom de 25% devraient apparaître

# %%
from scipy import misc
import matplotlib.pyplot as plt
face = misc.face(gray=True)
face_zoom = zoom(face,25)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,8))
ax1.imshow(face,cmap=plt.cm.gray)
ax2.imshow(face_zoom,cmap=plt.cm.gray)

# %% [markdown]
# ## Vidéos (12 et 13/30):
# [NumPy : Mathématiques, Statistiques ](https://www.youtube.com/watch?v=RwFiNlL4Q8g&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=12)
#
# [NumPy : Broadcasting ](https://www.youtube.com/watch?v=lIESSFHGalA&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=13)
#
# Soit A un ndarray (une matrice).
#
# Ecrivez une fonction standardiser(A) qui renvoie une version standardisée de la matrice A. Autrement dit qui renvoie
#
# >![image.png](data:image/png;base64,...)

# %%
def standardiser(A):
  # A : ndarray représentant la matrice à standardiser

# %% [markdown]
# ##(Bonus) Outils graphiques : 1) MathPlotLib : Vidéos (14 et 15/30):
# [MatPlotLib : Les Bases ](https://www.youtube.com/watch?v=O_OeWxpnUc0&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=14)
#
# [MatPlotLib : Graphiques Importants ](https://www.youtube.com/watch?v=MILtbfrMGL4&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=15)
#
# Soit
# *   x un ndarray représentant un dataset dont chaque ligne représente  un individu du dataset et chaque colonne une feature (une caractéristique)
# *   y un ndarray contenant les labels (sous forme numériques) correspondant à chaque indivu du dataset (autrement y[i] est le label de l'individu correspondant à x[i])
# *   names une liste contenant les noms (des String) des caractérisques
#
# Écrivez une méthode pairplot(x,y,f) générant tous les graphiques de type scatter obtenus en prenant toutes les paires de caractéristiques possibles et ce sur une seule figure en employant des subplots, en mettant les noms des features sur les axes et en utilisant y pour les couleurs.
#
# Donc si le dataset a n features la figure aura n² graphiques disposés sur n lignes et n colonnes.
#
#
# Vous testerez votre méthode sur le dataset de l'iris. Vous devriez obtenir une figure semblable à celle ci-dessous
#
# ![image.png](data:image/png;base64,...)

# %%
def scatter(x,y,names) :
  # x : un ndarray contenant le dataset
  # y : un ndarray contenant les labels (les targets)
  # names : une liste contenant la liste des noms des features

from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target
names = list(iris['feature_names'])

scatter(x,y,names)

# %% [markdown]
# ## Vidéos (17/30):
# [Panda : Introduction + Analyse du titanic](https://www.youtube.com/watch?v=zZkNOdBWgFQ&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=17)
# 1. Prenez le fichier titanix.xls afin d'importer les données du titanic dans un dataFrame panda que l'on appelera titanic
# 2. Supprimer les features (colonnes) 'name','sibsp', 'parch','ticket','fare','cabin', 'embarked','boat','body','home.dest'
# 3. Supprimer les valeurs du type NaN
# 4. A l'aide de boolean indexing, répartir les ages en 4 catégories en remplaçant les données de la colonne 'age' par
#   *   0 si age <= 0
#   *   1 si 20 < age <= 30
#   *   2 si 30 < age <= 40
#   *   3 si age > 40
#
#    Faites le de la manière la plus propre et la plus rigoureuse possible

# %%
import pandas as pd
titanic = ...

# %% [markdown]
# ## Vidéos (18/30):
# [Panda : Time Series](https://www.youtube.com/watch?v=qHRLG5hsW9I&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=18)
#
# 1. Prenez le fichier BTC-EUR.csv afin d'importer les données du Bitcoin, en les indexant par date, dans un dataFrame panda que l'on appelera bitcoins.
# 2. Ajoutez une colonne 'rollingMin' contenant la valeur du minimale du bitcoin sur les 20 derniers jours (en faisant un shift de 1 !)
# 3. Ajoutez une colonne 'rollingMax' contenant la valeur du maximale du bitcoin sur les 20 derniers jours (en faisant un shift de 1 !)
# 4. Ajoutez une colonne 'sell' qui contient -1 si la valeur de clôture du jour est strictement plus petite que le minimum des 28 derniers jours et 0 sinon
# 5. Ajoutez une colonne 'buy' qui contient 1 si la valeur de clôture jour est strictement plus grande que le maximum des 28 derniers jours et 0 sinon
# 6. (bonus) Sur une seule figure, tracez deux graphiques en ne prenant que les données de 2019 : un graphique avec les valeurs de clôture, minimal et maximal sur 28 jours et un graphique avec le temps en absisse et 'buy' et 'sell' en ordonnée.

# %%
bitcoin = ...

# %% [markdown]
# ## (Bonus) Outils Graphiques : 2) SeaBorn : Vidéos (19/30):
# [SeaBorn : Les plus beaux graphiques](https://www.youtube.com/watch?v=xYgfIRzNPlo&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=19)
# 1. Prenez le fichier iris.csv afin d'importer le dataSet des iris dans un dataFrame que nous appelerons iris
# 2. En une seule ligne de code, obtenez un graphique similaire à celui qui vous a été demandé dans la section consacrée à MalPlotlib.
# 3. Comparez le graphique obtenu en 2. avec celui obtenu avec MatPlotLib. Quelles sont les différences et quels sont les avantages de SeaBorn ?

# %%
import seaborn as sns
iris = ...

# %% [markdown]
# Réponse à la question 3. :

# %% [markdown]
# # Partie 2 : Exercices Machine Learning semaine 2

# %% [markdown]
# ## Exercice 1 : Tailles et poids d'individus
#
#
# 1.   Importez le fichier Taille-Poids.csv dans un dataFrame
# 2.   Supprimer la colonne 'nbId'
# 3.   Groupez les données par taille
# 4.   Calculer le poids moyen pour chaque taille et afficher cela dans un graphique
# 5.   Calculer le nombre de poids pour chaque taille et afficher cela dans un graphique dans la même figure que le graphique obtenu en 4. et cela à l'aide de subplot.
# 6.   Que pouvez-vous déduire comme lien (corrélation) entre le poids et la taille ?
# 7.   Que pouvez-vous dire d'autres sur les des données ?

# %% [markdown]
# Réponse aux questions 6. et 7. :

# %% [markdown]
# ## Exercice 2 : Détections de faux billets
# Pour détecter les faux billets, on se sert de trois tests : VWT, SWT, KWT.
# En fonction des résultats de ces tests on obtient soit 1 pour authentique soit 0 pour faux.
# 1.   Importez le fichier banknote_authentication.csv dans un dataFrame
# 2.   Grâce à SeaBorn, obtenez une figure avec un graphique par paire de features.
# 3.   Calculez la matrice de corrélation
# 4.   Affichez cette matrice grâce à Seaborn.
# 5.   Que pouvez-vous en déduire sur la corrélation des features ?

# %%
#code pour le 1 et 2

# %%
#code pour le 3 et 4

# %% [markdown]
# Réponse à la question 5. :
